# %% [markdown]
# ### Do the imports

# %%
from google.colab import auth
from google.cloud import bigquery
from google.auth import default
import pytz
import os
from datetime import date, datetime
import gspread
from google.colab import data_table
import matplotlib.pyplot as plt
from collections import defaultdict
import plotly.graph_objects as go
from IPython.display import display

# %% [markdown]
# ###Setup and a Useful Function:

# %%
data_table.enable_dataframe_formatter()

def run_query(bq_client, query):
  selection_result = bq_client.query(query)
  df = selection_result.to_dataframe()
  return df

# %% [markdown]
# ###Specify the project ID to be charged and create a BQ Client:

# %%
google_project_to_charge = "new-june2018-project"
bq_client = bigquery.Client(google_project_to_charge)

# %% [markdown]
# ### Authenticate using Google Colab auth package:

# %%
auth.authenticate_user(project_id=google_project_to_charge)
creds, _ = default()

# %% [markdown]
# ###Show Available TCGA Projects
#
# This table shows the datasets you can select from:

# %%
project_query = '''
  SELECT * FROM `isb-cgc-bq.ISB_Regulome_Explorer.projects_tcga`
  ORDER BY disease_code, key
'''
df = run_query(bq_client, project_query)
data_table.DataTable(df, include_index=True, num_rows_per_page=50)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>disease_code</th>
#       <th>description</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ACC</td>
#       <td>TCGA Adrenocortical Carcinoma (ACC) Manuscript</td>
#       <td>acc_11aug15</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BLCA</td>
#       <td>TCGA Bladder Cancer (BLCA) Manuscript</td>
#       <td>blca_20may13_manuscript_tumor_only</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BRCA</td>
#       <td>TCGA TCGA Breast Invasive Carcinoma (BRCA) Feb...</td>
#       <td>brca_03feb13</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BRCA</td>
#       <td>TCGA Breast Invasive Carcinoma (BRCA) Manuscript</td>
#       <td>brca_manuscript</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>COADREAD</td>
#       <td>TCGA Colorectal Adenocarcinoma (COAD, READ) Ma...</td>
#       <td>coadread_12apr12</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ESCA_STAD</td>
#       <td>TCGA Gastroesophageal Cancer (ESCA) Manuscript</td>
#       <td>esca_stad_08feb16</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>GBM</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) February 20...</td>
#       <td>gbm_06feb14_all</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>GBM</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) February 20...</td>
#       <td>gbm_06feb14_classical</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>GBM</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) February 20...</td>
#       <td>gbm_06feb14_mesenchymal</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>GBM</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) February 20...</td>
#       <td>gbm_06feb14_neural</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>GBM</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) February 20...</td>
#       <td>gbm_06feb14_proneural</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>GBM</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) Manuscript ...</td>
#       <td>gbm_2013_pub</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>HNSC</td>
#       <td>TCGA Glioblastoma Multiforme (GBM) Manuscript ...</td>
#       <td>hnsc_03feb13</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>KIRC</td>
#       <td>TCGA Kidney Renal Clear Cell Carcinoma (KIRC) ...</td>
#       <td>kirc_01oct12</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>LGG</td>
#       <td>TCGA Low Grade Glioma (LGG) October 2013</td>
#       <td>lgg_04oct13</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>LIHC</td>
#       <td>TCGA Liver Hepatocellular Carcinoma (LIHC) Man...</td>
#       <td>lihc_11oct16</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>LUAD</td>
#       <td>TCGA Lung Adenocarcinoma (LUAD) February 2013</td>
#       <td>luad_03feb13</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>LUSC</td>
#       <td>TCGA Lung Squamous Cell Carcinoma (LUSC) Febru...</td>
#       <td>lusc_03feb13</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>OV</td>
#       <td>TCGA Ovarian Serous Cystadenocarcinoma (OV) Fe...</td>
#       <td>ov_03feb13</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>PRAD</td>
#       <td>TCGA Prostate Adenocarcinoma (PRAD) Manuscript</td>
#       <td>prad_17aug15</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>SKCM</td>
#       <td>TCGA Skin Cutaneous Melanoma (SKCM) April 2014</td>
#       <td>skcm_01apr14_all</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>SKCM</td>
#       <td>TCGA Skin Cutaneous Melanoma (SKCM) April 2014...</td>
#       <td>skcm_01apr14_metastatic_tumor_only</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>STAD</td>
#       <td>TCGA Stomach Adenocarcinoma (STAD) Manuscript</td>
#       <td>stad_23jan14</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>THCA</td>
#       <td>TCGA Thyroid Carcinoma (THCA) Manuscript</td>
#       <td>thca_18oct14</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>UCEC</td>
#       <td>TCGA Uterine Corpus Endometrial Carcinoma (UCE...</td>
#       <td>ucec_28jun13</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ###Select the Project Number (0-24) From the Above Table You Wish to Explore
#
# The BQ tables are clustered by project key!

# %%
dataset_index = 15
key = df['key'].tolist()[dataset_index]

# %% [markdown]
# ###Specify the two feature types you want to compare:

# %%
#
# These are what the four-letter codes mean:
#
#  "Clinical": "CLIN",
#  "Somatic Copy Number": "CNVR",
#  "Gene Expression": "GEXP",
#  "Somatic Mutation": "GNAB",
#  "DNA Methylation": "METH",
#  "MicroRNA Expression": "MIRN",
#  "Protein Level - RPPA": "RPPA",

feature_1 = "GEXP"
feature_2 = "GEXP"

# %% [markdown]
# ###Set the parameters for what assocations you want to look at, and the maximum number of results:

# %%
min_logged_pvalue_bonf = 20
lower_correlation_value = 0.65
upper_correlation_value = 0.75
max_results = 200

# %% [markdown]
# ###Run the analysis:

# %%
analysis_query = '''
    WITH a1 as (SELECT id FROM `isb-cgc-bq.ISB_Regulome_Explorer.features_tcga`
                  WHERE source = "{feature_1}" AND dataset = "{dataset}"),
         b1 as (SELECT id FROM `isb-cgc-bq.ISB_Regulome_Explorer.features_tcga`
                  WHERE source = "{feature_2}" AND dataset = "{dataset}"),
         c1 as (SELECT * from `isb-cgc-bq.ISB_Regulome_Explorer.feature_associations_tcga`
                  WHERE (correlation >= {low_corr}) AND (correlation <= {high_corr})
                  AND logged_pvalue_bonf >= {pval}
                  AND dataset = "{dataset}")
    SELECT feature_1_id, feature_1, feature_2_id, feature_2, distance, logged_pvalue_bonf, logged_pvalue, correlation, num_samples,	dataset FROM c1
      INNER JOIN a1 on a1.id = c1.feature_1_id
      INNER JOIN b1 on b1.id = c1.feature_2_id
      ORDER BY ABS(correlation) desc LIMIT {lim}
    '''.format(feature_1=feature_1, feature_2=feature_2, dataset=key, low_corr=lower_correlation_value,
               high_corr=upper_correlation_value, pval=min_logged_pvalue_bonf, lim=max_results)
df = run_query(bq_client, analysis_query)
df
# Out:
#      feature_1_id                                       feature_1  \
# 0           18803     N:GEXP:IGFBP7:chr4:57897237:57976551:-:3490
# 1           18768    N:GEXP:IFI16:chr1:158969758:159024945:+:3428
# 2           18494    N:GEXP:HDAC7:chr12:48176507:48213763:-:51564
# 3           17148  N:GEXP:DENND3:chr8:142138720:142205906:+:22898
# 4           35669    N:GEXP:MLL3:chr7:151832010:152133090:-:58508
# ..            ...                                             ...
# 195         19218   N:GEXP:KLHL28:chr14:45393527:45431179:-:54813
# 196         33154    N:GEXP:CDK12:chr17:37617739:37690800:+:51755
# 197         20007      N:GEXP:MRC2:chr17:60704762:60770952:+:9902
# 198         16490       N:GEXP:CDC7:chr1:91966404:91991321:+:8317
# 199         22529   N:GEXP:SSC5D:chr19:55999870:56030466:+:284297
#
#      feature_2_id                                        feature_2  distance  \
# 0           38043     N:GEXP:THY1:chr11:119288655:119294246:-:7070      <NA>
# 1           36777   N:GEXP:PTPLAD2:chr9:21003623:21031635:-:401494      <NA>
# 2           18634     N:GEXP:HOMER3:chr19:19017769:19052041:-:9454      <NA>
# 3           18462   N:GEXP:HAPLN3:chr15:89420519:89438770:-:145864      <NA>
# 4           37060  N:GEXP:RNF168:chr3:196195657:196230639:-:165918      <NA>
# ..            ...                                              ...       ...
# 195         21567        N:GEXP:REST:chr4:57774042:57802010:+:5978      <NA>
# 196         38797        N:GEXP:ZFR:chr5:32354456:32444844:-:51663      <NA>
# 197         20795    N:GEXP:PDZD4:chrX:153067621:153096003:-:57595      <NA>
# 198         33181     N:GEXP:CENPI:chrX:100353178:100417978:+:2491      <NA>
# 199         22532       N:GEXP:SSPN:chr12:26348269:26405853:+:8082      <NA>
#
#      logged_pvalue_bonf  logged_pvalue  correlation  num_samples       dataset
# 0                  27.1           35.2         0.75          193  lihc_11oct16
# 1                  26.7           34.8         0.75          193  lihc_11oct16
# 2                  26.9           35.0         0.75          193  lihc_11oct16
# 3                  27.0           35.1         0.75          193  lihc_11oct16
# 4                  27.1           35.3         0.75          193  lihc_11oct16
# ..                  ...            ...          ...          ...           ...
# 195                26.8           35.0         0.75          193  lihc_11oct16
# 196                27.1           35.2         0.75          193  lihc_11oct16
# 197                27.3           35.4         0.75          193  lihc_11oct16
# 198                26.9           35.0         0.75          193  lihc_11oct16
# 199                27.1           35.2         0.75          193  lihc_11oct16
#
# [200 rows x 10 columns]

# %% [markdown]
# ###Select the Association Row Above You Want to Plot:

# %%
plot_row = 118

# %% [markdown]
# ### Pull the Plot Points Out:
#
# Note that we are using the ":"-separated lists of data values from the features table, which is convenient for plotting. For numerical analysis, use the tuple tables instead.

# %%
def pull_plot_points(bq_client, dataset, id):
  point_query = '''
    SELECT patient_values FROM `isb-cgc-bq.ISB_Regulome_Explorer.features_tcga`
      WHERE dataset = "{dataset}" AND id = {id}
    '''.format(dataset=dataset, id=id)
  df = run_query(bq_client, point_query)
  return df

def pull_patient_barcodes(bq_client, dataset):
  barcode_query = '''
    SELECT barcodes FROM `isb-cgc-bq.ISB_Regulome_Explorer.barcodes_tcga`
      WHERE dataset = "{dataset}"
    '''.format(dataset=dataset)
  df = run_query(bq_client, barcode_query)
  return df

fea_1= df['feature_1_id'].tolist()[plot_row]
label1 = df['feature_1'].tolist()[plot_row]
the_set = df['dataset'].tolist()[plot_row]
fea_2 = df['feature_2_id'].tolist()[plot_row]
label2 = df['feature_2'].tolist()[plot_row]

df2 = pull_plot_points(bq_client, the_set, fea_1)
points_x = df2['patient_values'].tolist()[0]

df3 = pull_plot_points(bq_client, the_set, fea_2)
points_y = df3['patient_values'].tolist()[0]

dfp = pull_patient_barcodes(bq_client, key)
barcodes = dfp['barcodes'].tolist()[0]

# Splitting on the ":" into arrays of values:
point_x_raw_array = points_x.split(':')
point_y_raw_array = points_y.split(':')
barcodes_array = barcodes.split(':')

# Only want to include points that are not "NA"!

num_points = len(point_x_raw_array)
x_num = []
y_num = []
bar_nums = []
for i in range(0, num_points):
  if point_x_raw_array[i] != "NA" and point_y_raw_array[i] != "NA":
    x_num.append(float(point_x_raw_array[i]))
    y_num.append(float(point_y_raw_array[i]))
    bar_nums.append(barcodes_array[i])

# %% [markdown]
# ### Plot the Association!
#
# With the data points pulled out, do the plot. <br>
# **NOTE: If two points are on top of each other, only one will show up in the hover tooltip!**

# %%
layout = go.Layout(xaxis=go.layout.XAxis(title=label1), yaxis=go.layout.YAxis(title=label2))

# see https://stackoverflow.com/questions/69278251/plotly-including-additional-data-in-hovertemplate
fig = go.Figure(go.Scatter(x=x_num, y=y_num, mode='markers', marker_symbol='circle',
                           customdata=bar_nums,
                           hovertemplate='patient ID: %{customdata}',
                           marker=dict(color='rgba(135, 206, 250, 0.1)',
                                       size=8,
                                       line=dict(color='MediumPurple', width=2))), layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d149a681-a5ad-40bf-99dc-9eb0d1e573ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d149a681-a5ad-40bf-99dc-9eb0d1e573ed")) {                    Plotly.newPlot(                        "d149a681-a5ad-40bf-99dc-9eb0d1e573ed",                        [{"customdata":["TCGA-BC-4072-01B","TCGA-BC-4073-01B","TCGA-BC-A10R-01A","TCGA-BC-A10S-01A","TCGA-BC-A10T-01A","TCGA-BC-A10U-01A","TCGA-BC-A10W-01A","TCGA-BC-A10X-01A","TCGA-BC-A10Y-01A","TCGA-BC-A10Z-01A","TCGA-BC-A110-01A","TCGA-BC-A112-01A","TCGA-BC-A216-01A","TCGA-BC-A217-01A","TCGA-BC-A3KF-01A","TCGA-BC-A3KG-01A","TCGA-BC-A5W4-01A","TCGA-BC-A69H-01A","TCGA-BC-A69I-01A","TCGA-BD-A2L6-01A","TCGA-BD-A3EP-01A","TCGA-BW-A5NO-01A","TCGA-BW-A5NP-01A","TCGA-BW-A5NQ-01A","TCGA-CC-5258-01A","TCGA-CC-5259-01A","TCGA-CC-5260-01A","TCGA-CC-5261-01A","TCGA-CC-5262-01A","TCGA-CC-5263-01A","TCGA-CC-5264-01A","TCGA-CC-A123-01A","TCGA-CC-A1HT-01A","TCGA-CC-A3M9-01A","TCGA-CC-A3MA-01A","TCGA-CC-A3MB-01A","TCGA-CC-A3MC-01A","TCGA-CC-A5UC-01A","TCGA-CC-A5UD-01A","TCGA-CC-A5UE-01A","TCGA-CC-A7IF-01A","TCGA-CC-A7IG-01A","TCGA-CC-A7IH-01A","TCGA-CC-A7II-01A","TCGA-CC-A7IJ-01A","TCGA-CC-A7IK-01A","TCGA-CC-A7IL-01A","TCGA-DD-A113-01A","TCGA-DD-A114-01A","TCGA-DD-A115-01A","TCGA-DD-A116-01A","TCGA-DD-A118-01A","TCGA-DD-A119-01A","TCGA-DD-A11A-01A","TCGA-DD-A11B-01A","TCGA-DD-A11C-01A","TCGA-DD-A11D-01A","TCGA-DD-A1EA-01A","TCGA-DD-A1EB-01A","TCGA-DD-A1EC-01A","TCGA-DD-A1ED-01A","TCGA-DD-A1EE-01A","TCGA-DD-A1EF-01A","TCGA-DD-A1EG-01A","TCGA-DD-A1EH-01A","TCGA-DD-A1EI-01A","TCGA-DD-A1EJ-01A","TCGA-DD-A1EK-01A","TCGA-DD-A1EL-01A","TCGA-DD-A39V-01A","TCGA-DD-A39W-01A","TCGA-DD-A39X-01A","TCGA-DD-A39Y-01A","TCGA-DD-A39Z-01A","TCGA-DD-A3A1-01A","TCGA-DD-A3A2-01A","TCGA-DD-A3A3-